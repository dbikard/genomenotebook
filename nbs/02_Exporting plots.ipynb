# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Exporting plots

# %% [markdown]
# You can save the current view of a plot using the interactive save tool from Bokeh. Depending on the size of your plot you might need to click on the three little dots to see the tool in the menu.
#
# You can also save plots programmatically using the `GenomeBrowser.save` function. Note that this function will only save the initial version of the plot and not the current view.
#
# Saving plots requires selenium and geckodriver. Please refer to the [Bokeh documentation](https://docs.bokeh.org/en/latest/docs/user_guide/output/export.html) in case of problem.

# %% [markdown]
# ## Saving to svg
# Plots can only be saved to svg if you initialise your GenomeBrowser using `output_backend="svg"`. When mutliple tracks are displayed, an individual svg file will be saved for each track, as well as a combined svg file.

# %%
import genomenotebook as gn
import os
import pandas as pd
from bokeh.io import output_notebook #|hide_line
import numpy as np #|hide_line
from nbdev.showdoc import * #|hide_line

# %%
output_notebook(hide_banner=True) #|hide_line

data_path = gn.get_example_data_dir()
gff_path = os.path.join(data_path, "MG1655_U00096.gff3")

data=pd.DataFrame(dict(x=np.arange(0,5000,100),
                       y=np.sin(np.arange(0,5000,100))))

g=gn.GenomeBrowser(gff_path=gff_path, 
                bounds=(0,5000),
                search=False)

track = g.add_track(height=100)
track.scatter(data=data, pos="x", y="y")
g.show()
g.save("test.svg")
# Out:
#   <div id="ac40b902-7dfb-4b68-a733-e948b84b1bad" data-root-id="p1316" style="display: contents;"></div>
# /home/sean/scripts/python/genomenotebook/genomenotebook/browser.py:374: UserWarning: If using WSL you can install chromedriver following these instructions:https://scottspence.com/posts/use-chrome-in-ubuntu-wsl
#                                   Also make sure the chromedriver-binary python package has the same major version number as your chrome install.
#                                   Check the chrome version using: google-chrome --version
#                                    Then use pip to force install of a web driver with a compatible version, for example:
#                                    pip install --force-reinstall -v "chromedriver-binary==121.0.6167.184.0"
#
#   warnings.warn("""If using WSL you can install chromedriver following these instructions:https://scottspence.com/posts/use-chrome-in-ubuntu-wsl
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 16
#      14 track.scatter(data=data, pos="x", y="y")
#      15 g.show()
# ---> 16 g.save("test.svg")
#
# File ~/scripts/python/genomenotebook/genomenotebook/browser.py:346, in save(self, fname, title)
#     343 for track in self.tracks:
#     344     heights.append(track.height)
# --> 346 save(plot.elements, heights, self.width, fname, title)
#
# File ~/scripts/python/genomenotebook/genomenotebook/browser.py:388, in save(elements, heights, width, fname, title)
#     384         browser=None
#     386 if ext == ".svg":
#     387     #export_svg(layout, filename=fname)
# --> 388     export_svgs(layout, filename=fname, webdriver=browser)
#     389     if len(heights)>1: # TODO: what is this?
#     390         total_height=sum(heights)
#
# File ~/miniconda3/envs/genomenotebook/lib/python3.11/site-packages/bokeh/io/export.py:206, in export_svgs(obj, filename, width, height, webdriver, timeout, state)
#     168 def export_svgs(obj: UIElement | Document, *, filename: str | None = None, width: int | None = None,
#     169         height: int | None = None, webdriver: WebDriver | None = None, timeout: int = 5, state: State | None = None) -> list[str]:
#     170     ''' Export the SVG-enabled plots within a layout. Each plot will result
#     171     in a distinct SVG file.
#     172
#    (...)
#     204
#     205     '''
# --> 206     svgs = get_svgs(obj, width=width, height=height, driver=webdriver, timeout=timeout, state=state)
#     208     if len(svgs) == 0:
#     209         log.warning("No SVG Plots were found.")
#
# File ~/miniconda3/envs/genomenotebook/lib/python3.11/site-packages/bokeh/io/export.py:292, in get_svgs(obj, driver, timeout, resources, width, height, state)
#     289 with open(tmp.path, mode="w", encoding="utf-8") as file:
#     290     file.write(html)
# --> 292 web_driver = driver if driver is not None else webdriver_control.get()
#     293 web_driver.get(f"file://{tmp.path}")
#     294 wait_until_render_complete(web_driver, timeout)
#
# File ~/miniconda3/envs/genomenotebook/lib/python3.11/site-packages/bokeh/io/webdriver.py:138, in _WebdriverState.get(self)
#     136 if not self.reuse or self.current is None:
#     137     self.reset()
# --> 138     self.current = self.create()
#     139 return self.current
#
# File ~/miniconda3/envs/genomenotebook/lib/python3.11/site-packages/bokeh/io/webdriver.py:142, in _WebdriverState.create(self, kind)
#     141 def create(self, kind: DriverKind | None = None) -> WebDriver:
# --> 142     driver = self._create(kind)
#     143     self._drivers.add(driver)
#     144     return driver
#
# File ~/miniconda3/envs/genomenotebook/lib/python3.11/site-packages/bokeh/io/webdriver.py:160, in _WebdriverState._create(self, kind)
#     157         self.kind = "firefox"
#     158         return driver
# --> 160     raise RuntimeError("Neither firefox and geckodriver nor a variant of chromium browser and " \
#     161                        "chromedriver are available on system PATH. You can install the former " \
#     162                        "with 'conda install -c conda-forge firefox geckodriver'.")
#     163 elif driver_kind == "chromium":
#     164     return create_chromium_webdriver()
#
# RuntimeError: Neither firefox and geckodriver nor a variant of chromium browser and chromedriver are available on system PATH. You can install the former with 'conda install -c conda-forge firefox geckodriver'.

# %% [markdown]
# ## Saving to png

# %% [markdown]
# You can increase the height and width to obtain a better resolution.

# %%
g=gn.GenomeBrowser(gff_path=gff_path,
                   bounds=(0,5000),
                   search=False,
                   height=200,
                   width=2000,
                   label_font_size="20pt")
g.save("test.png")

# %% [markdown]
# ## Saving to html
#
# You can save a plot as an interactive html file

# %%
g=gn.GenomeBrowser(gff_path=gff_path,
                   bounds=(0,5000),
                   search=False,
                   height=200,
                   width=500,
                   label_font_size="20pt")
g.save_html("test.html", title="interactive graph")

# %%
#| hide
# Remove test files

# List all files in the directory
files = os.listdir()

# Iterate over the files
for file in files:
    if file.endswith(".png") or file.endswith(".svg") or file.endswith(".html"):
        
        try:
            # Delete the file
            os.remove(file)
        except PermissionError:
            print(f"Permission denied to delete file '{file}'.")
        except FileNotFoundError:
            print(f"File '{file}' not found.")
